# %%
import pandas as pd
T=pd.read_excel("E:/VB/City Temperature Assignment.xlsx")

#To get the informations about the data
T.info()

T.SURAT.mean()
T.SURAT.median()
T.SURAT.mode()
T.SURAT.var()
T.SURAT.std()
T.SURAT.skew()
T.SURAT.kurt()
T.SURAT.hist()
T.SURAT.value_counts()

T.SHIMLA.mean()
T.SHIMLA.median()
T.SHIMLA.mode()
T.SHIMLA.var()
T.SHIMLA.std()
T.SHIMLA.skew()
T.SHIMLA.kurt()
T.SHIMLA.hist()
T.SHIMLA.value_counts()

T.MUMBAI.mean()
T.MUMBAI.median()
T.MUMBAI.mode()
T.MUMBAI.var()
T.MUMBAI.std()
T.MUMBAI.skew()
T.MUMBAI.kurt()
T.MUMBAI.hist()
T.MUMBAI.value_counts()

T.BANGALORE.mean()
T.BANGALORE.median()
T.BANGALORE.mode()
T.BANGALORE.var()
T.BANGALORE.std()
T.BANGALORE.skew()
T.BANGALORE.kurt()
T.BANGALORE.hist()
T.BANGALORE.value_counts()

T.HYDERABAD.mean()
T.HYDERABAD.median()
T.HYDERABAD.mode()
T.HYDERABAD.var()
T.HYDERABAD.std()
T.HYDERABAD.skew()
T.HYDERABAD.kurt()
T.HYDERABAD.hist()
T.HYDERABAD.value_counts()

#Shimla has humid temperature in comparison with all other places.
#Therefore persons who prefer humid places would go for Shimla and warm places would go for Mumbai and Surat.
